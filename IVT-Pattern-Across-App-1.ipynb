# %% [markdown]
# <a href="https://colab.research.google.com/github/mel0ca/Traffic-Analysis/blob/main/IVT-Pattern-Across-App-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ad Traffic Analysis
# **Objective :**
# This analysis focuses on examining ad traffic patterns across six different applications to uncover the underlying reasons behind invalid traffic (IVT) classification. The goal is to identify what specific behaviors, metrics, or anomalies lead certain apps to be flagged as early or late IVT while others maintain legitimate traffic status. By comparing these patterns, the study aims to provide a clear understanding of the distinguishing factors between IVT and non-IVT traffic.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://docs.google.com/spreadsheets/d/1MTnRFZvwCDI1lnrKsQXau-zqcPzDpkg_wsnkP0wkcaA/gviz/tq?tqx=out:csv"
df = pd.read_csv(url)

print("Loaded Data")
df.head()
# Out:
# Loaded Data
#    Unnamed: 0     Total Data Date  unique_idfas  unique_ips  unique_uas  \
# 0         NaN                 NaN       1191603     1189884          28
# 1         NaN  2025-09-11 0:00:00         93345       93340          22
# 2         NaN  2025-09-12 0:00:00        515646      515307          25
# 3         NaN  2025-09-13 0:00:00        406993      406729          25
# 4         NaN  2025-09-14 0:00:00        400917      400668          26
#
#    total_requests  requests_per_idfa  impressions  impressions_per_idfa  \
# 0         1770702           1.485983            0                     0
# 1           99280           1.063581            0                     0
# 2          649515           1.259614            0                     0
# 3          473346           1.163032            0                     0
# 4          467152           1.165209            0                     0
#
#    idfa_ip_ratio  idfa_ua_ratio       IVT
# 0       1.001445   42557.250000  0.004276
# ...

# %% [markdown]
# Data Cleaning: Removing extra spaces

# %%
df = df.drop(columns=['Unnamed: 0'], errors='ignore')

# %% [markdown]
# Date to datetime conversion

# %%
df['Total Data Date'] = pd.to_datetime(df['Total Data Date'], errors='coerce')

# %%
df.head()
# Out:
#   Total Data Date  unique_idfas  unique_ips  unique_uas  total_requests  \
# 0             NaT       1191603     1189884          28         1770702
# 1      2025-09-11         93345       93340          22           99280
# 2      2025-09-12        515646      515307          25          649515
# 3      2025-09-13        406993      406729          25          473346
# 4      2025-09-14        400917      400668          26          467152
#
#    requests_per_idfa  impressions  impressions_per_idfa  idfa_ip_ratio  \
# 0           1.485983            0                     0       1.001445
# 1           1.063581            0                     0       1.000054
# 2           1.259614            0                     0       1.000658
# 3           1.163032            0                     0       1.000649
# 4           1.165209            0                     0       1.000621
#
#    idfa_ua_ratio       IVT
# 0   42557.250000  0.004276
# 1    4242.954545  0.003456
# ...

# %%
# Checking for Missing values
print(df.isnull().sum())
# Out:
# Total Data Date         1
# unique_idfas            0
# unique_ips              0
# unique_uas              0
# total_requests          0
# requests_per_idfa       0
# impressions             0
# impressions_per_idfa    0
# idfa_ip_ratio           0
# idfa_ua_ratio           0
# IVT                     0
# dtype: int64

# %%
# Checking for Non Null values and Datatypes
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Total Data Date       89 non-null     datetime64[ns]
#  1   unique_idfas          90 non-null     int64
#  2   unique_ips            90 non-null     int64
#  3   unique_uas            90 non-null     int64
#  4   total_requests        90 non-null     int64
#  5   requests_per_idfa     90 non-null     float64
#  6   impressions           90 non-null     int64
#  7   impressions_per_idfa  90 non-null     int64
#  8   idfa_ip_ratio         90 non-null     float64
#  9   idfa_ua_ratio         90 non-null     float64
#  10  IVT                   90 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(6)
# memory usage: 7.9 KB
# None

# %%
df.describe()
# Out:
#                      Total Data Date  unique_idfas    unique_ips  unique_uas  \
# count                             89  9.000000e+01  9.000000e+01   90.000000
# mean   2025-09-13 07:04:43.146067200  4.867137e+04  4.864164e+04   19.433333
# min              2025-09-11 00:00:00  3.535000e+03  3.535000e+03   17.000000
# 25%              2025-09-12 10:00:00  9.190000e+03  9.190000e+03   18.000000
# 50%              2025-09-13 07:00:00  1.375300e+04  1.375300e+04   19.000000
# 75%              2025-09-14 04:00:00  2.268400e+04  2.268075e+04   20.000000
# max              2025-09-15 01:00:00  1.191603e+06  1.189884e+06   28.000000
# std                              NaN  1.452255e+05  1.450471e+05    2.088223
#
#        total_requests  requests_per_idfa  impressions  impressions_per_idfa  \
# count    9.000000e+01          90.000000         90.0                  90.0
# mean     5.902340e+04           1.042722          0.0                   0.0
# ...

# %%
parameters = ['requests_per_idfa', 'impressions_per_idfa', 'idfa_ip_ratio', 'idfa_ua_ratio']

for i in parameters:
    plt.figure(figsize=(7,4))
    sns.histplot(df[i], kde=True)
    plt.title(f'Distribution of {i}')
    plt.show()

# %% [markdown]
# # Observations
# * requests_per_idfa: The distribution is heavily skewed towards values around 1, Idicating legitimate traffic where each unique device makes a small number of requests.
#
# * impressions_per_idfa: The distribution is entirely at 0, indicating that very few, if any, ad impressions are being served per unique device. further indicating requests are made but ads are not actually displayed.
#
# * idfa_ip_ratio: This ratio is tightly clustered around 1, suggesting that the number of unique devices is very close to the number of unique IP address.
#
# * idfa_ua_ratio: This distribution is highly skewed with a long tail extending to very high values. This indicates that in some cases, a very large number of unique devices are associated with a single or very few User-Agents.

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Total Data Date'], df['idfa_ua_ratio'], label='idfa_ua_ratio')
plt.plot(df['Total Data Date'], df['idfa_ip_ratio'], label='idfa_ip_ratio')
plt.plot(df['Total Data Date'], df['requests_per_idfa'], label='requests_per_idfa')
plt.legend()
plt.title("Trend of Ratios Over Time")
plt.xlabel("Date")
plt.ylabel("Ratio Value")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * The idfa_ua_ratio shows significant spikes over time, This reinforces the idea that the idfa_ua_ratio is a primary driver of anomalies and likely related to IVT.

# %%
plt.figure(figsize=(8,4))
sns.lineplot(data=df, x='Total Data Date', y='IVT')
plt.title("IVT Flag Over Time")
plt.show()

# %% [markdown]
# * This plot shows fluctuations in the IVT flag over time.

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation between Metrics")
plt.show()

# %% [markdown]
# * Strong positive correlation between the idfa_ua_ratio and the IVT is a significant indicator of invalid traffic.
# * Other metrics like requests_per_idfa and idfa_ip_ratio would likely show weaker correlations with the IVT flag.

# %% [markdown]
# **Patterns Leading to IVT**
#
# * Non-IVT Apps:
# Stable request patterns, low IDFA-UA ratio, no abnormal spikes, consistent traffic → never flagged.
#
# * Early-IVT Apps:
# Sudden spikes in idfa_ua_ratio and request volume → flagged by system quickly.
#
# * Late-IVT Apps:
# Gradual increase in device clustering and traffic anomalies → flagged later.
#
# * Common Factor:
# High IDFA-UA ratio + zero impressions + sudden request surges correlate strongly with IVT marking.

# %% [markdown]
# ### Graph-Based Insights
#
# * Requests per IDFA: Mostly stable (~1), minor variations.
# * Impressions per IDFA: Flat at 0 -> indicates fake or unserved requests.
# * IDFA-IP Ratio: ~1 across apps -> normal, not a IVT factor.
# * IDFA-UA Ratio: Shows large spikes in IVT apps -> clear signal for detection.
# * IVT Trend: Peaks correspond with high idfa_ua_ratio -> strong visual correlation between device spoofing and IVT marking.

# %% [markdown]
# ##### Conclusion
#
# The analysis indicates that the IVT detection system primarily flags apps exhibiting irregular or unnatural traffic behavior. Key indicators include high concentrations of devices sharing the same User-Agent, sudden spikes in ad requests without corresponding impressions, and abrupt fluctuations in traffic metrics. Apps with consistent and balanced traffic patterns, reflected in low IDFA-to-User-Agent ratios, tend to avoid IVT classification. Conversely, those showing clustered or erratic activity are flagged as IVT—either early or late—depending on when these anomalies arise.
